# %%
# Run this Python script to download the model
import urllib.request
import os

# Create Models directory if it doesn't exist
models_dir = r"C:\Users\HP\Desktop\SLIIT DOCS\Y4\Research project\DANCEFORGE AI\DANCEFORGE-AI\Models"
os.makedirs(models_dir, exist_ok=True)

# Download pose landmarker model
model_url = 'https://storage.googleapis.com/mediapipe-models/pose_landmarker/pose_landmarker_full/float16/latest/pose_landmarker_full.task'
model_path = os.path.join(models_dir, 'pose_landmarker_full.task')

print(f"Downloading pose model to: {model_path}")
urllib.request.urlretrieve(model_url, model_path)
print("✓ Download complete!")
# Out:
# ...
# ✓ Download complete!
